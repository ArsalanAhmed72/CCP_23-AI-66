# %%
import os, sys, time, random, warnings
from collections import deque
from pathlib import Path
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models, callbacks, optimizers, applications
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, f1_score
warnings.filterwarnings('ignore')
print("TensorFlow:", tf.__version__)
print("OpenCV:", cv2.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.20.0
# OpenCV: 4.13.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/CCP/FER.zip"
extract_path = "/content/FER"

# unzip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(" Unzipped successfully!")
# Out:
#  Unzipped successfully!

# %%
from pathlib import Path

TRAIN_DIR = Path("/content/FER/train")
TEST_DIR  = Path("/content/FER/test")

# emotions detect
EMOTIONS = sorted([d.name for d in TRAIN_DIR.iterdir() if d.is_dir()])
NUM_CLASSES = len(EMOTIONS)

print("Emotion classes:", EMOTIONS)
print("Num classes:", NUM_CLASSES)

# correct function
def count_images(folder, emotion):
    return len(list((folder / emotion).glob("*")))  # jpg/png both safe

# per-class counts
print("\nTrain images per class:")
for e in EMOTIONS:
    print(e, ":", count_images(TRAIN_DIR, e))

print("\nTest images per class:")
for e in EMOTIONS:
    print(e, ":", count_images(TEST_DIR, e))

train_count = sum(count_images(TRAIN_DIR, e) for e in EMOTIONS)
test_count  = sum(count_images(TEST_DIR, e) for e in EMOTIONS)

print("\nTotal Train images:", train_count)
print("Total Test images:", test_count)
# Out:
# Emotion classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Num classes: 7
#
# Train images per class:
# angry : 3995
# disgust : 436
# fear : 4097
# happy : 7215
# neutral : 4965
# sad : 4830
# surprise : 3171
#
# Test images per class:
# angry : 958
# disgust : 111
# fear : 1024
# happy : 1774
# neutral : 1233
# sad : 1247
# surprise : 831
#
# Total Train images: 28709
# Total Test images: 7178

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for ax, folder, title in zip(
    axes,
    [TRAIN_DIR, TEST_DIR],
    ['Train Set Distribution', 'Test Set Distribution']
):

    counts = {
        e: count_images(folder, e)
        for e in EMOTIONS
    }

    values = list(counts.values())
    labels = list(counts.keys())

    # PIE CHART
    ax.pie(
        values,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90,
        colors=plt.cm.Set2(np.linspace(0, 1, len(counts)))
    )

    ax.set_title(title, fontsize=13, fontweight='bold')

plt.tight_layout()
plt.savefig('class_distribution_pie.png', dpi=150, bbox_inches='tight')
plt.show()

train_total = sum(count_images(TRAIN_DIR, e) for e in EMOTIONS)
test_total  = sum(count_images(TEST_DIR, e) for e in EMOTIONS)

print("Total train samples:", train_total)
print("Total test samples:", test_total)
# Out:
# Total train samples: 28709
# Total test samples: 7178

# %%
IMG_SIZE_GRAY = 48
IMG_SIZE_COLOR = 96
BATCH_SIZE = 64
EPOCHS_SCRATCH = 50
EPOCHS_FINETUNE = 20

def preprocess_face_gray(img_bgr):
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)

    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    eq = clahe.apply(blurred)

    resized = cv2.resize(eq, (IMG_SIZE_GRAY, IMG_SIZE_GRAY))
    norm = resized.astype('float32') / 255.0

    return norm[..., np.newaxis]


def preprocess_face_color(img_bgr):
    rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(rgb, (IMG_SIZE_COLOR, IMG_SIZE_COLOR))

    return applications.mobilenet_v2.preprocess_input(
        resized.astype('float32')
    )

print("Preprocessing functions Completed")
# Out:
# Preprocessing functions Completed

# %%
fig, axes = plt.subplots(len(EMOTIONS), 5, figsize=(14, 2.5 * len(EMOTIONS)))

steps = ['Original', 'Grayscale', 'Gaussian Blur', 'Enhanced Contrast Image', 'Final Processed Image']

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

for row, emotion in enumerate(EMOTIONS):

    img_list = list((TRAIN_DIR / emotion).glob("*.jpg"))

    # safety check
    if len(img_list) == 0:
        print(f" No images found in {emotion}")
        continue

    img_path = img_list[0]
    img_bgr = cv2.imread(str(img_path))

    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    eq = clahe.apply(blurred)
    resized = cv2.resize(eq, (IMG_SIZE_GRAY, IMG_SIZE_GRAY))

    imgs = [
        cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB),
        gray,
        blurred,
        eq,
        resized
    ]

    cmaps = [None, 'gray', 'gray', 'gray', 'gray']

    for col, (im, cmap, step) in enumerate(zip(imgs, cmaps, steps)):
        axes[row, col].imshow(im, cmap=cmap)
        axes[row, col].axis('off')

        if row == 0:
            axes[row, col].set_title(step, fontsize=10, fontweight='bold')

        if col == 0:
            axes[row, col].set_ylabel(emotion, fontsize=9, rotation=90, labelpad=10)

plt.suptitle('Preprocessing Pipeline per Emotion Class', fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig('preprocessing_pipeline.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
def preprocess_gray(file_path, label):  # For both CNN & VGG
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=1)
    image = tf.image.resize(image, (IMG_SIZE_GRAY, IMG_SIZE_GRAY))
    image = tf.cast(image, tf.float32) / 255.0
    return image, label


def preprocess_color(file_path, label):  # for MobileNet
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (IMG_SIZE_COLOR, IMG_SIZE_COLOR))
    image = tf.keras.applications.mobilenet_v2.preprocess_input(
        tf.cast(image, tf.float32)
    )
    return image, label


# AUGMENTATION

def apply_augmentation(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, 0.1)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    return image, label

# DATASET BUILDER

def create_dataset(data_dir, preprocess_fn, augment=False, shuffle=True):

    paths, labels = [], []

    for idx, emotion in enumerate(EMOTIONS):
        img_files = list((data_dir / emotion).glob("*.jpg"))

        paths.extend([str(p) for p in img_files])
        labels.extend([idx] * len(img_files))

    dataset = tf.data.Dataset.from_tensor_slices(
        (paths, tf.one_hot(labels, NUM_CLASSES))
    )

    if shuffle:
        dataset = dataset.shuffle(len(paths), seed=42)

    dataset = dataset.map(preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE)

    if augment:
        dataset = dataset.map(apply_augmentation, num_parallel_calls=tf.data.AUTOTUNE)

    dataset = dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return dataset

# BUILD DATASETS

train_gray = create_dataset(TRAIN_DIR, preprocess_gray, augment=True)
val_gray   = create_dataset(TEST_DIR, preprocess_gray, augment=False, shuffle=False)

train_color = create_dataset(TRAIN_DIR, preprocess_color, augment=True)
val_color   = create_dataset(TEST_DIR, preprocess_color, augment=False, shuffle=False)

# SUMMARY

print("Dataset Summary")
print("Gray train batches :", len(train_gray))
print("Gray val batches   :", len(val_gray))
print("Color train batches:", len(train_color))
print("Color val batches  :", len(val_color))
# Out:
# Dataset Summary
# Gray train batches : 449
# Gray val batches   : 113
# Color train batches: 449
# Color val batches  : 113

# %%
# MODEL BUILD
def build_cnn(input_shape=(48, 48, 1), NUM_CLASSES=7):

    inp = layers.Input(shape=input_shape, name='input')

    # First Block with 32 filters
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.25)(x)

    # Second Block with 64 filters
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.25)(x)

    # Third Block with 128 filters
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.25)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)

    out = layers.Dense(NUM_CLASSES, activation='softmax')(x)

    model = models.Model(inputs=inp, outputs=out, name='build_cnn')

    return model


scratch_model = build_cnn()
scratch_model.summary()

print(f"\nTrainable params: {scratch_model.count_params():,}")
# Out:
# Model: "build_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 323,047 (1.23 MB)
#  Trainable params: 322,151 (1.23 MB)
#  Non-trainable params: 896 (3.50 KB)
# Trainable params: 323,047

# %%
def pretrained_model(input_shape=(96, 96, 3), num_classes=7, trainable=False):

    base = MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )

    # Freeze or fine-tune backbone
    if not trainable:
        base.trainable = False
    else:
        base.trainable = True

        # fine-tune last 30 layers only
        for layer in base.layers[:-30]:
            layer.trainable = False
        for layer in base.layers[-30:]:
            layer.trainable = True

    inp = layers.Input(shape=input_shape, name='input_color')

    x = base(inp, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.4)(x)

    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    out = layers.Dense(num_classes, activation='softmax')(x)

    name = 'mobilenetv2_frozen' if not trainable else 'mobilenetv2_finetuned'
    model = models.Model(inp, out, name=name)

    return model


# TEST
pretrained_frozen_model = pretrained_model(trainable=False)
pretrained_frozen_model.summary()

print(f"\nTrainable params: {pretrained_frozen_model.count_params():,}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "mobilenetv2_frozen"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_color (InputLayer)        │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_96             │ (None, 3, 3, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,046,983 (11.62 MB)
#  Trainable params: 788,999 (3.01 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Trainable params: 3,046,983

# %%
def vggdouble_convblock(x, filters, dropout_rate=0.3, name=''):
    x = layers.Conv2D(filters, 3, padding='same', name=f'{name}_conv1')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters, 3, padding='same', name=f'{name}_conv2')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(dropout_rate)(x)
    return x


def vggstyle_model(input_shape=(48, 48, 1), num_classes=7):
    inp = layers.Input(shape=input_shape, name='input_vgg')

    x = vggdouble_convblock(inp, 32,  dropout_rate=0.25, name='block1')
    x = vggdouble_convblock(x,   64,  dropout_rate=0.25, name='block2')
    x = vggdouble_convblock(x,   128, dropout_rate=0.30, name='block3')

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    out = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inp, out, name='vgg_style')
    return model

vgg_model = vggstyle_model()
vgg_model.summary()
print(f"\nTrainable params: {vgg_model.count_params():,}")
# Out:
# Model: "vgg_style"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_vgg (InputLayer)          │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 487,399 (1.86 MB)
#  Trainable params: 486,503 (1.86 MB)
#  Non-trainable params: 896 (3.50 KB)
# Trainable params: 487,399

# %%
def get_callbacks(model_name):
    return [
        callbacks.ModelCheckpoint(
            filepath=f'best_{model_name}.keras',
            monitor='val_accuracy', save_best_only=True, verbose=1),
        callbacks.EarlyStopping(
            monitor='val_accuracy', patience=8,
            restore_best_weights=True, verbose=1),
        callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.5, patience=4,
            min_lr=1e-6, verbose=1),
    ]

# %%
def compile_and_train(model, train_ds, val_ds, epochs, lr=1e-3, model_name='model'):
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    t0 = time.time()
    history = model.fit(
        train_ds, validation_data=val_ds,
        epochs=epochs,
        callbacks=get_callbacks(model_name),
        verbose=1
    )
    elapsed = time.time() - t0
    print(f"\n⏱  Training time: {elapsed/60:.1f} min")
    return history, elapsed

# %%
def plot_history(history, title):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    for ax, metric in zip(axes, ['accuracy', 'loss']):
        ax.plot(history.history[metric],       label='Train', linewidth=2)
        ax.plot(history.history[f'val_{metric}'], label='Val',   linewidth=2)
        ax.set_title(f'{title} — {metric.capitalize()}', fontsize=12)
        ax.set_xlabel('Epoch')
        ax.legend()
        ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f'{title.lower().replace(" ","_")}_history.png',
                dpi=150, bbox_inches='tight')
    plt.show()

# %%
history_scratch, time_scratch = compile_and_train(
    scratch_model,
    train_gray,
    val_gray,
    epochs=EPOCHS_SCRATCH,
    lr=1e-3,
    model_name="CNN"
)
# Out:
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2459 - loss: 1.8801
# Epoch 1: val_accuracy improved from None to 0.25313, saving model to best_CNN.keras
#
# Epoch 1: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 34s 42ms/step - accuracy: 0.2996 - loss: 1.7397 - val_accuracy: 0.2531 - val_loss: 1.9370 - learning_rate: 0.0010
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4439 - loss: 1.4402
# Epoch 2: val_accuracy improved from 0.25313 to 0.44901, saving model to best_CNN.keras
#
# Epoch 2: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.4635 - loss: 1.4021 - val_accuracy: 0.4490 - val_loss: 1.4277 - learning_rate: 0.0010
# Epoch 3/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5093 - loss: 1.2864
# Epoch 3: val_accuracy improved from 0.44901 to 0.53274, saving model to best_CNN.keras
#
# Epoch 3: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.5159 - loss: 1.2703 - val_accuracy: 0.5327 - val_loss: 1.2116 - learning_rate: 0.0010
# Epoch 4/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5433 - loss: 1.2070
# Epoch 4: val_accuracy improved from 0.53274 to 0.53734, saving model to best_CNN.keras
#
# Epoch 4: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5466 - loss: 1.1966 - val_accuracy: 0.5373 - val_loss: 1.2297 - learning_rate: 0.0010
# Epoch 5/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5625 - loss: 1.1577
# Epoch 5: val_accuracy improved from 0.53734 to 0.57509, saving model to best_CNN.keras
#
# Epoch 5: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5626 - loss: 1.1583 - val_accuracy: 0.5751 - val_loss: 1.1228 - learning_rate: 0.0010
# Epoch 6/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5840 - loss: 1.1084
# Epoch 6: val_accuracy improved from 0.57509 to 0.57732, saving model to best_CNN.keras
#
# Epoch 6: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5809 - loss: 1.1177 - val_accuracy: 0.5773 - val_loss: 1.1057 - learning_rate: 0.0010
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5923 - loss: 1.0877
# Epoch 7: val_accuracy did not improve from 0.57732
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.5925 - loss: 1.0875 - val_accuracy: 0.5632 - val_loss: 1.1693 - learning_rate: 0.0010
# Epoch 8/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6049 - loss: 1.0594
# Epoch 8: val_accuracy improved from 0.57732 to 0.58289, saving model to best_CNN.keras
#
# Epoch 8: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6044 - loss: 1.0614 - val_accuracy: 0.5829 - val_loss: 1.1123 - learning_rate: 0.0010
# Epoch 9/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6154 - loss: 1.0275
# Epoch 9: val_accuracy improved from 0.58289 to 0.60518, saving model to best_CNN.keras
#
# Epoch 9: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6103 - loss: 1.0411 - val_accuracy: 0.6052 - val_loss: 1.0826 - learning_rate: 0.0010
# Epoch 10/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6224 - loss: 0.9995
# Epoch 10: val_accuracy did not improve from 0.60518
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6178 - loss: 1.0158 - val_accuracy: 0.5975 - val_loss: 1.0618 - learning_rate: 0.0010
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6286 - loss: 0.9938
# Epoch 11: val_accuracy improved from 0.60518 to 0.61619, saving model to best_CNN.keras
#
# Epoch 11: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6261 - loss: 0.9951 - val_accuracy: 0.6162 - val_loss: 1.0450 - learning_rate: 0.0010
# Epoch 12/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6290 - loss: 0.9826
# Epoch 12: val_accuracy did not improve from 0.61619
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6304 - loss: 0.9844 - val_accuracy: 0.5899 - val_loss: 1.1090 - learning_rate: 0.0010
# Epoch 13/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6428 - loss: 0.9550
# Epoch 13: val_accuracy improved from 0.61619 to 0.61981, saving model to best_CNN.keras
#
# Epoch 13: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6393 - loss: 0.9652 - val_accuracy: 0.6198 - val_loss: 1.0262 - learning_rate: 0.0010
# Epoch 14/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6437 - loss: 0.9559
# Epoch 14: val_accuracy did not improve from 0.61981
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.6428 - loss: 0.9606 - val_accuracy: 0.5911 - val_loss: 1.0887 - learning_rate: 0.0010
# Epoch 15/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6475 - loss: 0.9366
# Epoch 15: val_accuracy improved from 0.61981 to 0.63291, saving model to best_CNN.keras
#
# Epoch 15: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6492 - loss: 0.9366 - val_accuracy: 0.6329 - val_loss: 1.0119 - learning_rate: 0.0010
# Epoch 16/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6526 - loss: 0.9201
# Epoch 16: val_accuracy improved from 0.63291 to 0.64544, saving model to best_CNN.keras
#
# Epoch 16: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6522 - loss: 0.9267 - val_accuracy: 0.6454 - val_loss: 0.9594 - learning_rate: 0.0010
# Epoch 17/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6550 - loss: 0.9060
# Epoch 17: val_accuracy did not improve from 0.64544
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.6565 - loss: 0.9143 - val_accuracy: 0.6314 - val_loss: 1.0135 - learning_rate: 0.0010
# Epoch 18/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6638 - loss: 0.8965
# Epoch 18: val_accuracy did not improve from 0.64544
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6599 - loss: 0.9010 - val_accuracy: 0.6190 - val_loss: 1.0285 - learning_rate: 0.0010
# Epoch 19/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6716 - loss: 0.8880
# Epoch 19: val_accuracy did not improve from 0.64544
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6667 - loss: 0.8930 - val_accuracy: 0.6048 - val_loss: 1.0711 - learning_rate: 0.0010
# Epoch 20/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6761 - loss: 0.8684
# Epoch 20: val_accuracy did not improve from 0.64544
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6720 - loss: 0.8818 - val_accuracy: 0.6229 - val_loss: 1.0500 - learning_rate: 0.0010
# Epoch 21/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6863 - loss: 0.8396
# Epoch 21: val_accuracy improved from 0.64544 to 0.64948, saving model to best_CNN.keras
#
# Epoch 21: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6897 - loss: 0.8285 - val_accuracy: 0.6495 - val_loss: 0.9412 - learning_rate: 5.0000e-04
# Epoch 22/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7019 - loss: 0.8085
# Epoch 22: val_accuracy improved from 0.64948 to 0.66300, saving model to best_CNN.keras
#
# Epoch 22: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6989 - loss: 0.8113 - val_accuracy: 0.6630 - val_loss: 0.9326 - learning_rate: 5.0000e-04
# Epoch 23/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7041 - loss: 0.7967
# Epoch 23: val_accuracy did not improve from 0.66300
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7002 - loss: 0.8008 - val_accuracy: 0.6599 - val_loss: 0.9365 - learning_rate: 5.0000e-04
# Epoch 24/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7062 - loss: 0.7866
# Epoch 24: val_accuracy did not improve from 0.66300
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7050 - loss: 0.7950 - val_accuracy: 0.6532 - val_loss: 0.9577 - learning_rate: 5.0000e-04
# Epoch 25/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7099 - loss: 0.7797
# Epoch 25: val_accuracy did not improve from 0.66300
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7050 - loss: 0.7859 - val_accuracy: 0.6601 - val_loss: 0.9344 - learning_rate: 5.0000e-04
# Epoch 26/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7159 - loss: 0.7683
# Epoch 26: val_accuracy improved from 0.66300 to 0.66383, saving model to best_CNN.keras
#
# Epoch 26: finished saving model to best_CNN.keras
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7114 - loss: 0.7766 - val_accuracy: 0.6638 - val_loss: 0.9401 - learning_rate: 5.0000e-04
# Epoch 27/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7203 - loss: 0.7500
# Epoch 27: val_accuracy improved from 0.66383 to 0.66565, saving model to best_CNN.keras
#
# Epoch 27: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7193 - loss: 0.7445 - val_accuracy: 0.6656 - val_loss: 0.9329 - learning_rate: 2.5000e-04
# Epoch 28/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7230 - loss: 0.7301
# Epoch 28: val_accuracy did not improve from 0.66565
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7222 - loss: 0.7415 - val_accuracy: 0.6606 - val_loss: 0.9380 - learning_rate: 2.5000e-04
# Epoch 29/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7346 - loss: 0.7210
# Epoch 29: val_accuracy improved from 0.66565 to 0.66606, saving model to best_CNN.keras
#
# Epoch 29: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7270 - loss: 0.7314 - val_accuracy: 0.6661 - val_loss: 0.9297 - learning_rate: 2.5000e-04
# Epoch 30/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7369 - loss: 0.7090
# Epoch 30: val_accuracy did not improve from 0.66606
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7288 - loss: 0.7249 - val_accuracy: 0.6599 - val_loss: 0.9356 - learning_rate: 2.5000e-04
# Epoch 31/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7302 - loss: 0.7137
# Epoch 31: val_accuracy improved from 0.66606 to 0.66690, saving model to best_CNN.keras
#
# Epoch 31: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7294 - loss: 0.7174 - val_accuracy: 0.6669 - val_loss: 0.9361 - learning_rate: 2.5000e-04
# Epoch 32/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7366 - loss: 0.7099
# Epoch 32: val_accuracy did not improve from 0.66690
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7343 - loss: 0.7132 - val_accuracy: 0.6644 - val_loss: 0.9454 - learning_rate: 2.5000e-04
# Epoch 33/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7335 - loss: 0.7083
# Epoch 33: val_accuracy improved from 0.66690 to 0.66704, saving model to best_CNN.keras
#
# Epoch 33: finished saving model to best_CNN.keras
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7356 - loss: 0.7085 - val_accuracy: 0.6670 - val_loss: 0.9507 - learning_rate: 2.5000e-04
# Epoch 34/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7443 - loss: 0.6850
# Epoch 34: val_accuracy improved from 0.66704 to 0.67080, saving model to best_CNN.keras
#
# Epoch 34: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7413 - loss: 0.6902 - val_accuracy: 0.6708 - val_loss: 0.9366 - learning_rate: 1.2500e-04
# Epoch 35/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7471 - loss: 0.6805
# Epoch 35: val_accuracy did not improve from 0.67080
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7461 - loss: 0.6853 - val_accuracy: 0.6697 - val_loss: 0.9453 - learning_rate: 1.2500e-04
# Epoch 36/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7388 - loss: 0.6868
# Epoch 36: val_accuracy improved from 0.67080 to 0.67108, saving model to best_CNN.keras
#
# Epoch 36: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7426 - loss: 0.6838 - val_accuracy: 0.6711 - val_loss: 0.9443 - learning_rate: 1.2500e-04
# Epoch 37/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7455 - loss: 0.6808
# Epoch 37: val_accuracy did not improve from 0.67108
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7455 - loss: 0.6788 - val_accuracy: 0.6702 - val_loss: 0.9408 - learning_rate: 1.2500e-04
# Epoch 38/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7519 - loss: 0.6676
# Epoch 38: val_accuracy improved from 0.67108 to 0.67136, saving model to best_CNN.keras
#
# Epoch 38: finished saving model to best_CNN.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7514 - loss: 0.6664 - val_accuracy: 0.6714 - val_loss: 0.9388 - learning_rate: 6.2500e-05
# Epoch 39/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7516 - loss: 0.6703
# Epoch 39: val_accuracy did not improve from 0.67136
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7522 - loss: 0.6652 - val_accuracy: 0.6691 - val_loss: 0.9431 - learning_rate: 6.2500e-05
# Epoch 40/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7526 - loss: 0.6586
# Epoch 40: val_accuracy did not improve from 0.67136
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7506 - loss: 0.6604 - val_accuracy: 0.6668 - val_loss: 0.9435 - learning_rate: 6.2500e-05
# Epoch 41/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7512 - loss: 0.6604
# Epoch 41: val_accuracy did not improve from 0.67136
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.7505 - loss: 0.6654 - val_accuracy: 0.6680 - val_loss: 0.9388 - learning_rate: 6.2500e-05
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7545 - loss: 0.6555
# Epoch 42: val_accuracy did not improve from 0.67136
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.7534 - loss: 0.6628 - val_accuracy: 0.6711 - val_loss: 0.9432 - learning_rate: 3.1250e-05
# Epoch 43/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7529 - loss: 0.6553
# Epoch 43: val_accuracy did not improve from 0.67136
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7544 - loss: 0.6578 - val_accuracy: 0.6697 - val_loss: 0.9459 - learning_rate: 3.1250e-05
# Epoch 44/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7566 - loss: 0.6596
# Epoch 44: val_accuracy did not improve from 0.67136
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7551 - loss: 0.6562 - val_accuracy: 0.6704 - val_loss: 0.9455 - learning_rate: 3.1250e-05
# Epoch 45/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7520 - loss: 0.6636
# Epoch 45: val_accuracy did not improve from 0.67136
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7526 - loss: 0.6609 - val_accuracy: 0.6708 - val_loss: 0.9428 - learning_rate: 3.1250e-05
# Epoch 46/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7552 - loss: 0.6504
# Epoch 46: val_accuracy did not improve from 0.67136
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7559 - loss: 0.6504 - val_accuracy: 0.6707 - val_loss: 0.9425 - learning_rate: 1.5625e-05
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 38.
#
# ⏱  Training time: 7.6 min

# %%
plot_history(history_scratch, 'CNN')

# %%
print(" TRAINING MODEL 2a: MobileNetV2 Frozen Backbone")

pretrained_frozen_model = pretrained_model(trainable=False)

history_frozen, time_frozen = compile_and_train(
    pretrained_frozen_model,
    train_color,
    val_color,
    epochs=20,
    lr=1e-3,
    model_name="mobilenet_frozen"
)

plot_history(history_frozen, "MobileNetV2 Frozen")
# Out:
#  TRAINING MODEL 2a: MobileNetV2 Frozen Backbone
# Epoch 1/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3314 - loss: 1.7388
# Epoch 1: val_accuracy improved from None to 0.44873, saving model to best_mobilenet_frozen.keras
#
# Epoch 1: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 68s 104ms/step - accuracy: 0.3740 - loss: 1.6151 - val_accuracy: 0.4487 - val_loss: 1.4473 - learning_rate: 0.0010
# Epoch 2/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4258 - loss: 1.4897
# Epoch 2: val_accuracy improved from 0.44873 to 0.46378, saving model to best_mobilenet_frozen.keras
#
# Epoch 2: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.4311 - loss: 1.4812 - val_accuracy: 0.4638 - val_loss: 1.4049 - learning_rate: 0.0010
# Epoch 3/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4501 - loss: 1.4369
# Epoch 3: val_accuracy improved from 0.46378 to 0.48342, saving model to best_mobilenet_frozen.keras
#
# Epoch 3: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 23s 35ms/step - accuracy: 0.4530 - loss: 1.4333 - val_accuracy: 0.4834 - val_loss: 1.3582 - learning_rate: 0.0010
# Epoch 4/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4642 - loss: 1.3974
# Epoch 4: val_accuracy improved from 0.48342 to 0.49136, saving model to best_mobilenet_frozen.keras
#
# Epoch 4: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.4656 - loss: 1.3969 - val_accuracy: 0.4914 - val_loss: 1.3494 - learning_rate: 0.0010
# Epoch 5/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4772 - loss: 1.3708
# Epoch 5: val_accuracy did not improve from 0.49136
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - accuracy: 0.4767 - loss: 1.3717 - val_accuracy: 0.4896 - val_loss: 1.3403 - learning_rate: 0.0010
# Epoch 6/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4916 - loss: 1.3378
# Epoch 6: val_accuracy improved from 0.49136 to 0.49262, saving model to best_mobilenet_frozen.keras
#
# Epoch 6: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.4848 - loss: 1.3475 - val_accuracy: 0.4926 - val_loss: 1.3331 - learning_rate: 0.0010
# Epoch 7/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4968 - loss: 1.3222
# Epoch 7: val_accuracy improved from 0.49262 to 0.49652, saving model to best_mobilenet_frozen.keras
#
# Epoch 7: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.4953 - loss: 1.3256 - val_accuracy: 0.4965 - val_loss: 1.3187 - learning_rate: 0.0010
# Epoch 8/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5001 - loss: 1.3071
# Epoch 8: val_accuracy improved from 0.49652 to 0.49694, saving model to best_mobilenet_frozen.keras
#
# Epoch 8: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - accuracy: 0.4995 - loss: 1.3096 - val_accuracy: 0.4969 - val_loss: 1.3208 - learning_rate: 0.0010
# Epoch 9/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5125 - loss: 1.2785
# Epoch 9: val_accuracy improved from 0.49694 to 0.51115, saving model to best_mobilenet_frozen.keras
#
# Epoch 9: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.5080 - loss: 1.2882 - val_accuracy: 0.5111 - val_loss: 1.3039 - learning_rate: 0.0010
# Epoch 10/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5194 - loss: 1.2570
# Epoch 10: val_accuracy improved from 0.51115 to 0.51546, saving model to best_mobilenet_frozen.keras
#
# Epoch 10: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.5126 - loss: 1.2716 - val_accuracy: 0.5155 - val_loss: 1.2914 - learning_rate: 0.0010
# Epoch 11/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5167 - loss: 1.2595
# Epoch 11: val_accuracy did not improve from 0.51546
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5177 - loss: 1.2611 - val_accuracy: 0.5078 - val_loss: 1.2918 - learning_rate: 0.0010
# Epoch 12/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5327 - loss: 1.2377
# Epoch 12: val_accuracy improved from 0.51546 to 0.52048, saving model to best_mobilenet_frozen.keras
#
# Epoch 12: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - accuracy: 0.5280 - loss: 1.2439 - val_accuracy: 0.5205 - val_loss: 1.2811 - learning_rate: 0.0010
# Epoch 13/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5344 - loss: 1.2165
# Epoch 13: val_accuracy did not improve from 0.52048
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5307 - loss: 1.2284 - val_accuracy: 0.5137 - val_loss: 1.2881 - learning_rate: 0.0010
# Epoch 14/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5349 - loss: 1.2128
# Epoch 14: val_accuracy improved from 0.52048 to 0.52145, saving model to best_mobilenet_frozen.keras
#
# Epoch 14: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.5377 - loss: 1.2101 - val_accuracy: 0.5215 - val_loss: 1.2736 - learning_rate: 0.0010
# Epoch 15/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5432 - loss: 1.2001
# Epoch 15: val_accuracy improved from 0.52145 to 0.52271, saving model to best_mobilenet_frozen.keras
#
# Epoch 15: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - accuracy: 0.5406 - loss: 1.2018 - val_accuracy: 0.5227 - val_loss: 1.2801 - learning_rate: 0.0010
# Epoch 16/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5488 - loss: 1.1879
# Epoch 16: val_accuracy improved from 0.52271 to 0.52327, saving model to best_mobilenet_frozen.keras
#
# Epoch 16: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - accuracy: 0.5452 - loss: 1.1901 - val_accuracy: 0.5233 - val_loss: 1.2743 - learning_rate: 0.0010
# Epoch 17/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5587 - loss: 1.1595
# Epoch 17: val_accuracy did not improve from 0.52327
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.5521 - loss: 1.1729 - val_accuracy: 0.5201 - val_loss: 1.2754 - learning_rate: 0.0010
# Epoch 18/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5566 - loss: 1.1619
# Epoch 18: val_accuracy improved from 0.52327 to 0.53469, saving model to best_mobilenet_frozen.keras
#
# Epoch 18: finished saving model to best_mobilenet_frozen.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.5582 - loss: 1.1664 - val_accuracy: 0.5347 - val_loss: 1.2662 - learning_rate: 0.0010
# Epoch 19/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5635 - loss: 1.1448
# Epoch 19: val_accuracy did not improve from 0.53469
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.5603 - loss: 1.1512 - val_accuracy: 0.5301 - val_loss: 1.2671 - learning_rate: 0.0010
# Epoch 20/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5690 - loss: 1.1226
# Epoch 20: val_accuracy did not improve from 0.53469
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.5645 - loss: 1.1398 - val_accuracy: 0.5233 - val_loss: 1.2750 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 18.
#
# ⏱  Training time: 5.9 min

# %%
print("TRAINING MODEL 2b: MobileNetV2 Fine-tuned")

finetuned_model = pretrained_model(trainable=True)
history_finetune, time_finetune = compile_and_train(
    finetuned_model, train_color, val_color,
    epochs=EPOCHS_FINETUNE, lr=1e-4,
    model_name='mobilenet_finetuned'
)
plot_history(history_finetune, 'MobileNetV2 Fine-tuned')
# Out:
# TRAINING MODEL 2b: MobileNetV2 Fine-tuned
# Epoch 1/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3278 - loss: 1.7348
# Epoch 1: val_accuracy improved from None to 0.44804, saving model to best_mobilenet_finetuned.keras
#
# Epoch 1: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 73ms/step - accuracy: 0.3983 - loss: 1.5622 - val_accuracy: 0.4480 - val_loss: 1.4375 - learning_rate: 1.0000e-04
# Epoch 2/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5091 - loss: 1.2952
# Epoch 2: val_accuracy improved from 0.44804 to 0.51045, saving model to best_mobilenet_finetuned.keras
#
# Epoch 2: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.5175 - loss: 1.2777 - val_accuracy: 0.5104 - val_loss: 1.2905 - learning_rate: 1.0000e-04
# Epoch 3/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5750 - loss: 1.1375
# Epoch 3: val_accuracy did not improve from 0.51045
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.5754 - loss: 1.1377 - val_accuracy: 0.5099 - val_loss: 1.2888 - learning_rate: 1.0000e-04
# Epoch 4/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6174 - loss: 1.0261
# Epoch 4: val_accuracy improved from 0.51045 to 0.53371, saving model to best_mobilenet_finetuned.keras
#
# Epoch 4: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - accuracy: 0.6178 - loss: 1.0288 - val_accuracy: 0.5337 - val_loss: 1.2312 - learning_rate: 1.0000e-04
# Epoch 5/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6590 - loss: 0.9186
# Epoch 5: val_accuracy improved from 0.53371 to 0.56464, saving model to best_mobilenet_finetuned.keras
#
# Epoch 5: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.6576 - loss: 0.9234 - val_accuracy: 0.5646 - val_loss: 1.1751 - learning_rate: 1.0000e-04
# Epoch 6/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7050 - loss: 0.8013
# Epoch 6: val_accuracy did not improve from 0.56464
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.6998 - loss: 0.8185 - val_accuracy: 0.5645 - val_loss: 1.2055 - learning_rate: 1.0000e-04
# Epoch 7/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7502 - loss: 0.6887
# Epoch 7: val_accuracy did not improve from 0.56464
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.7412 - loss: 0.7102 - val_accuracy: 0.5606 - val_loss: 1.2664 - learning_rate: 1.0000e-04
# Epoch 8/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7846 - loss: 0.5939
# Epoch 8: val_accuracy improved from 0.56464 to 0.57607, saving model to best_mobilenet_finetuned.keras
#
# Epoch 8: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - accuracy: 0.7780 - loss: 0.6093 - val_accuracy: 0.5761 - val_loss: 1.2871 - learning_rate: 1.0000e-04
# Epoch 9/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8217 - loss: 0.5085
# Epoch 9: val_accuracy did not improve from 0.57607
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.8096 - loss: 0.5312 - val_accuracy: 0.5613 - val_loss: 1.5053 - learning_rate: 1.0000e-04
# Epoch 10/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8595 - loss: 0.4011
# Epoch 10: val_accuracy did not improve from 0.57607
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.8608 - loss: 0.3938 - val_accuracy: 0.5730 - val_loss: 1.5358 - learning_rate: 5.0000e-05
# Epoch 11/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8871 - loss: 0.3214
# Epoch 11: val_accuracy did not improve from 0.57607
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.8839 - loss: 0.3298 - val_accuracy: 0.5692 - val_loss: 1.6874 - learning_rate: 5.0000e-05
# Epoch 12/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9066 - loss: 0.2702
# Epoch 12: val_accuracy improved from 0.57607 to 0.59641, saving model to best_mobilenet_finetuned.keras
#
# Epoch 12: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - accuracy: 0.9008 - loss: 0.2849 - val_accuracy: 0.5964 - val_loss: 1.6706 - learning_rate: 5.0000e-05
# Epoch 13/20
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9168 - loss: 0.2427
# Epoch 13: val_accuracy improved from 0.59641 to 0.59947, saving model to best_mobilenet_finetuned.keras
#
# Epoch 13: finished saving model to best_mobilenet_finetuned.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.9123 - loss: 0.2532 - val_accuracy: 0.5995 - val_loss: 1.7177 - learning_rate: 5.0000e-05
# Epoch 14/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9302 - loss: 0.2044
# Epoch 14: val_accuracy improved from 0.59947 to 0.60379, saving model to best_mobilenet_finetuned.keras
#
# Epoch 14: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.9307 - loss: 0.2017 - val_accuracy: 0.6038 - val_loss: 1.7991 - learning_rate: 2.5000e-05
# Epoch 15/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9425 - loss: 0.1679
# Epoch 15: val_accuracy improved from 0.60379 to 0.60964, saving model to best_mobilenet_finetuned.keras
#
# Epoch 15: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.9416 - loss: 0.1710 - val_accuracy: 0.6096 - val_loss: 1.9063 - learning_rate: 2.5000e-05
# Epoch 16/20
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9472 - loss: 0.1553
# Epoch 16: val_accuracy improved from 0.60964 to 0.61089, saving model to best_mobilenet_finetuned.keras
#
# Epoch 16: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.9459 - loss: 0.1564 - val_accuracy: 0.6109 - val_loss: 1.9613 - learning_rate: 2.5000e-05
# Epoch 17/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9502 - loss: 0.1469
# Epoch 17: val_accuracy did not improve from 0.61089
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.9504 - loss: 0.1457 - val_accuracy: 0.6094 - val_loss: 2.0718 - learning_rate: 2.5000e-05
# Epoch 18/20
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9557 - loss: 0.1303
# Epoch 18: val_accuracy improved from 0.61089 to 0.61103, saving model to best_mobilenet_finetuned.keras
#
# Epoch 18: finished saving model to best_mobilenet_finetuned.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.9564 - loss: 0.1273 - val_accuracy: 0.6110 - val_loss: 2.0659 - learning_rate: 1.2500e-05
# Epoch 19/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9610 - loss: 0.1161
# Epoch 19: val_accuracy did not improve from 0.61103
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9607 - loss: 0.1179 - val_accuracy: 0.6081 - val_loss: 2.1237 - learning_rate: 1.2500e-05
# Epoch 20/20
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9628 - loss: 0.1090
# Epoch 20: val_accuracy did not improve from 0.61103
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9627 - loss: 0.1085 - val_accuracy: 0.6055 - val_loss: 2.1690 - learning_rate: 1.2500e-05
# Restoring model weights from the end of the best epoch: 18.
#
# ⏱  Training time: 5.5 min

# %%
print("TRAINING MODEL 3: VGG-Style Double Conv Block")

vgg_model = vggstyle_model()
history_vgg, time_vgg = compile_and_train(
    vgg_model, train_gray, val_gray,
    epochs=EPOCHS_SCRATCH, lr=1e-3, model_name='vgg_style'
)
plot_history(history_vgg, 'VGG-Style')
# Out:
# TRAINING MODEL 3: VGG-Style Double Conv Block
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2307 - loss: 1.8442
# Epoch 1: val_accuracy improved from None to 0.24868, saving model to best_vgg_style.keras
#
# Epoch 1: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.2572 - loss: 1.7845 - val_accuracy: 0.2487 - val_loss: 1.9181 - learning_rate: 0.0010
# Epoch 2/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3521 - loss: 1.6219
# Epoch 2: val_accuracy improved from 0.24868 to 0.31039, saving model to best_vgg_style.keras
#
# Epoch 2: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.3796 - loss: 1.5674 - val_accuracy: 0.3104 - val_loss: 1.7379 - learning_rate: 0.0010
# Epoch 3/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4370 - loss: 1.4485
# Epoch 3: val_accuracy improved from 0.31039 to 0.46141, saving model to best_vgg_style.keras
#
# Epoch 3: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.4469 - loss: 1.4272 - val_accuracy: 0.4614 - val_loss: 1.3952 - learning_rate: 0.0010
# Epoch 4/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4767 - loss: 1.3623
# Epoch 4: val_accuracy improved from 0.46141 to 0.49707, saving model to best_vgg_style.keras
#
# Epoch 4: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.4812 - loss: 1.3480 - val_accuracy: 0.4971 - val_loss: 1.2749 - learning_rate: 0.0010
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5006 - loss: 1.3063
# Epoch 5: val_accuracy improved from 0.49707 to 0.50906, saving model to best_vgg_style.keras
#
# Epoch 5: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5033 - loss: 1.2946 - val_accuracy: 0.5091 - val_loss: 1.2658 - learning_rate: 0.0010
# Epoch 6/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5210 - loss: 1.2518
# Epoch 6: val_accuracy improved from 0.50906 to 0.51616, saving model to best_vgg_style.keras
#
# Epoch 6: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5210 - loss: 1.2555 - val_accuracy: 0.5162 - val_loss: 1.2933 - learning_rate: 0.0010
# Epoch 7/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5321 - loss: 1.2301
# Epoch 7: val_accuracy improved from 0.51616 to 0.54361, saving model to best_vgg_style.keras
#
# Epoch 7: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5357 - loss: 1.2237 - val_accuracy: 0.5436 - val_loss: 1.1799 - learning_rate: 0.0010
# Epoch 8/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5452 - loss: 1.1949
# Epoch 8: val_accuracy did not improve from 0.54361
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.5454 - loss: 1.1978 - val_accuracy: 0.5258 - val_loss: 1.2502 - learning_rate: 0.0010
# Epoch 9/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5539 - loss: 1.1714
# Epoch 9: val_accuracy improved from 0.54361 to 0.55740, saving model to best_vgg_style.keras
#
# Epoch 9: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - accuracy: 0.5572 - loss: 1.1718 - val_accuracy: 0.5574 - val_loss: 1.1655 - learning_rate: 0.0010
# Epoch 10/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5651 - loss: 1.1566
# Epoch 10: val_accuracy did not improve from 0.55740
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5652 - loss: 1.1533 - val_accuracy: 0.5251 - val_loss: 1.2533 - learning_rate: 0.0010
# Epoch 11/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5704 - loss: 1.1369
# Epoch 11: val_accuracy improved from 0.55740 to 0.57077, saving model to best_vgg_style.keras
#
# Epoch 11: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.5701 - loss: 1.1358 - val_accuracy: 0.5708 - val_loss: 1.1317 - learning_rate: 0.0010
# Epoch 12/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5739 - loss: 1.1257
# Epoch 12: val_accuracy did not improve from 0.57077
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.5794 - loss: 1.1214 - val_accuracy: 0.5616 - val_loss: 1.1228 - learning_rate: 0.0010
# Epoch 13/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5811 - loss: 1.1089
# Epoch 13: val_accuracy did not improve from 0.57077
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5854 - loss: 1.1052 - val_accuracy: 0.5614 - val_loss: 1.1448 - learning_rate: 0.0010
# Epoch 14/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5939 - loss: 1.0888
# Epoch 14: val_accuracy did not improve from 0.57077
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5910 - loss: 1.0884 - val_accuracy: 0.5460 - val_loss: 1.2296 - learning_rate: 0.0010
# Epoch 15/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5924 - loss: 1.0813
# Epoch 15: val_accuracy did not improve from 0.57077
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.5961 - loss: 1.0776 - val_accuracy: 0.5471 - val_loss: 1.1868 - learning_rate: 0.0010
# Epoch 16/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6040 - loss: 1.0603
# Epoch 16: val_accuracy improved from 0.57077 to 0.58568, saving model to best_vgg_style.keras
#
# Epoch 16: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6019 - loss: 1.0698 - val_accuracy: 0.5857 - val_loss: 1.0622 - learning_rate: 0.0010
# Epoch 17/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6004 - loss: 1.0653
# Epoch 17: val_accuracy improved from 0.58568 to 0.59919, saving model to best_vgg_style.keras
#
# Epoch 17: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6073 - loss: 1.0499 - val_accuracy: 0.5992 - val_loss: 1.0671 - learning_rate: 0.0010
# Epoch 18/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6199 - loss: 1.0206
# Epoch 18: val_accuracy did not improve from 0.59919
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6157 - loss: 1.0327 - val_accuracy: 0.5815 - val_loss: 1.1126 - learning_rate: 0.0010
# Epoch 19/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6207 - loss: 1.0125
# Epoch 19: val_accuracy did not improve from 0.59919
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6165 - loss: 1.0243 - val_accuracy: 0.5946 - val_loss: 1.0661 - learning_rate: 0.0010
# Epoch 20/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6215 - loss: 1.0128
# Epoch 20: val_accuracy did not improve from 0.59919
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.6217 - loss: 1.0133 - val_accuracy: 0.5970 - val_loss: 1.0573 - learning_rate: 0.0010
# Epoch 21/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6289 - loss: 0.9982
# Epoch 21: val_accuracy did not improve from 0.59919
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.6252 - loss: 1.0112 - val_accuracy: 0.5889 - val_loss: 1.0912 - learning_rate: 0.0010
# Epoch 22/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6293 - loss: 0.9922
# Epoch 22: val_accuracy did not improve from 0.59919
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6274 - loss: 0.9964 - val_accuracy: 0.5907 - val_loss: 1.0926 - learning_rate: 0.0010
# Epoch 23/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6315 - loss: 0.9882
# Epoch 23: val_accuracy improved from 0.59919 to 0.60518, saving model to best_vgg_style.keras
#
# Epoch 23: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6303 - loss: 0.9888 - val_accuracy: 0.6052 - val_loss: 1.0414 - learning_rate: 0.0010
# Epoch 24/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6344 - loss: 0.9797
# Epoch 24: val_accuracy did not improve from 0.60518
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6372 - loss: 0.9815 - val_accuracy: 0.5913 - val_loss: 1.0834 - learning_rate: 0.0010
# Epoch 25/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6386 - loss: 0.9736
# Epoch 25: val_accuracy improved from 0.60518 to 0.62817, saving model to best_vgg_style.keras
#
# Epoch 25: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6377 - loss: 0.9729 - val_accuracy: 0.6282 - val_loss: 0.9894 - learning_rate: 0.0010
# Epoch 26/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6433 - loss: 0.9577
# Epoch 26: val_accuracy did not improve from 0.62817
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.6415 - loss: 0.9641 - val_accuracy: 0.6197 - val_loss: 1.0003 - learning_rate: 0.0010
# Epoch 27/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6486 - loss: 0.9503
# Epoch 27: val_accuracy did not improve from 0.62817
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6442 - loss: 0.9532 - val_accuracy: 0.6096 - val_loss: 1.0367 - learning_rate: 0.0010
# Epoch 28/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6509 - loss: 0.9424
# Epoch 28: val_accuracy did not improve from 0.62817
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.6476 - loss: 0.9493 - val_accuracy: 0.6220 - val_loss: 1.0072 - learning_rate: 0.0010
# Epoch 29/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6596 - loss: 0.9225
# Epoch 29: val_accuracy improved from 0.62817 to 0.63096, saving model to best_vgg_style.keras
#
# Epoch 29: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6547 - loss: 0.9351 - val_accuracy: 0.6310 - val_loss: 0.9783 - learning_rate: 0.0010
# Epoch 30/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6600 - loss: 0.9240
# Epoch 30: val_accuracy did not improve from 0.63096
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6551 - loss: 0.9317 - val_accuracy: 0.6304 - val_loss: 0.9971 - learning_rate: 0.0010
# Epoch 31/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6589 - loss: 0.9146
# Epoch 31: val_accuracy did not improve from 0.63096
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6585 - loss: 0.9248 - val_accuracy: 0.6275 - val_loss: 1.0008 - learning_rate: 0.0010
# Epoch 32/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6588 - loss: 0.9281
# Epoch 32: val_accuracy did not improve from 0.63096
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6602 - loss: 0.9249 - val_accuracy: 0.6043 - val_loss: 1.0696 - learning_rate: 0.0010
# Epoch 33/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6673 - loss: 0.9052
# Epoch 33: val_accuracy improved from 0.63096 to 0.63500, saving model to best_vgg_style.keras
#
# Epoch 33: finished saving model to best_vgg_style.keras
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.6602 - loss: 0.9117 - val_accuracy: 0.6350 - val_loss: 0.9851 - learning_rate: 0.0010
# Epoch 34/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6728 - loss: 0.8836
# Epoch 34: val_accuracy improved from 0.63500 to 0.64851, saving model to best_vgg_style.keras
#
# Epoch 34: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6764 - loss: 0.8758 - val_accuracy: 0.6485 - val_loss: 0.9464 - learning_rate: 5.0000e-04
# Epoch 35/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6837 - loss: 0.8548
# Epoch 35: val_accuracy improved from 0.64851 to 0.64948, saving model to best_vgg_style.keras
#
# Epoch 35: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.6848 - loss: 0.8546 - val_accuracy: 0.6495 - val_loss: 0.9450 - learning_rate: 5.0000e-04
# Epoch 36/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6912 - loss: 0.8398
# Epoch 36: val_accuracy did not improve from 0.64948
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6871 - loss: 0.8517 - val_accuracy: 0.6447 - val_loss: 0.9624 - learning_rate: 5.0000e-04
# Epoch 37/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6872 - loss: 0.8385
# Epoch 37: val_accuracy did not improve from 0.64948
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6887 - loss: 0.8458 - val_accuracy: 0.6344 - val_loss: 0.9833 - learning_rate: 5.0000e-04
# Epoch 38/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6977 - loss: 0.8222
# Epoch 38: val_accuracy improved from 0.64948 to 0.65171, saving model to best_vgg_style.keras
#
# Epoch 38: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6924 - loss: 0.8326 - val_accuracy: 0.6517 - val_loss: 0.9487 - learning_rate: 5.0000e-04
# Epoch 39/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6952 - loss: 0.8253
# Epoch 39: val_accuracy did not improve from 0.65171
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.6929 - loss: 0.8309 - val_accuracy: 0.6452 - val_loss: 0.9520 - learning_rate: 5.0000e-04
# Epoch 40/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7031 - loss: 0.8113
# Epoch 40: val_accuracy improved from 0.65171 to 0.65297, saving model to best_vgg_style.keras
#
# Epoch 40: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7045 - loss: 0.8080 - val_accuracy: 0.6530 - val_loss: 0.9462 - learning_rate: 2.5000e-04
# Epoch 41/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7113 - loss: 0.7914
# Epoch 41: val_accuracy improved from 0.65297 to 0.65965, saving model to best_vgg_style.keras
#
# Epoch 41: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7088 - loss: 0.7944 - val_accuracy: 0.6597 - val_loss: 0.9378 - learning_rate: 2.5000e-04
# Epoch 42/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7122 - loss: 0.7894
# Epoch 42: val_accuracy did not improve from 0.65965
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7080 - loss: 0.7971 - val_accuracy: 0.6545 - val_loss: 0.9349 - learning_rate: 2.5000e-04
# Epoch 43/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7085 - loss: 0.7936
# Epoch 43: val_accuracy did not improve from 0.65965
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.7082 - loss: 0.7940 - val_accuracy: 0.6492 - val_loss: 0.9471 - learning_rate: 2.5000e-04
# Epoch 44/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7100 - loss: 0.7895
# Epoch 44: val_accuracy did not improve from 0.65965
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7106 - loss: 0.7855 - val_accuracy: 0.6583 - val_loss: 0.9347 - learning_rate: 2.5000e-04
# Epoch 45/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7115 - loss: 0.7815
# Epoch 45: val_accuracy did not improve from 0.65965
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7075 - loss: 0.7881 - val_accuracy: 0.6555 - val_loss: 0.9294 - learning_rate: 2.5000e-04
# Epoch 46/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7160 - loss: 0.7730
# Epoch 46: val_accuracy did not improve from 0.65965
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.7114 - loss: 0.7809 - val_accuracy: 0.6587 - val_loss: 0.9328 - learning_rate: 2.5000e-04
# Epoch 47/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7149 - loss: 0.7748
# Epoch 47: val_accuracy did not improve from 0.65965
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7140 - loss: 0.7797 - val_accuracy: 0.6595 - val_loss: 0.9268 - learning_rate: 2.5000e-04
# Epoch 48/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7191 - loss: 0.7614
# Epoch 48: val_accuracy did not improve from 0.65965
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.7169 - loss: 0.7698 - val_accuracy: 0.6525 - val_loss: 0.9455 - learning_rate: 2.5000e-04
# Epoch 49/50
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7168 - loss: 0.7696
# Epoch 49: val_accuracy improved from 0.65965 to 0.66188, saving model to best_vgg_style.keras
#
# Epoch 49: finished saving model to best_vgg_style.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7154 - loss: 0.7768 - val_accuracy: 0.6619 - val_loss: 0.9270 - learning_rate: 2.5000e-04
# Epoch 50/50
# 447/449 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7246 - loss: 0.7598
# Epoch 50: val_accuracy did not improve from 0.66188
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.7188 - loss: 0.7709 - val_accuracy: 0.6528 - val_loss: 0.9504 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 49.
#
# ⏱  Training time: 8.5 min

# %%
CNN = tf.keras.models.load_model('best_CNN.keras')
frozen = tf.keras.models.load_model('best_mobilenet_frozen.keras')
finetune = tf.keras.models.load_model('best_mobilenet_finetuned.keras')
vgg = tf.keras.models.load_model('best_vgg_style.keras')
print("All models loaded.")
# Out:
# All models loaded.

# %%
def evaluate_model(model, dataset, model_name):


    y_true, y_pred = [], []

    for x, y in dataset:
        preds = model.predict(x, verbose=0)

        y_pred.extend(np.argmax(preds, axis=1))
        y_true.extend(np.argmax(y.numpy(), axis=1))

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    print("MODEL:", model_name)

    print(classification_report(y_true, y_pred, target_names=EMOTIONS))

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=EMOTIONS,
                yticklabels=EMOTIONS)

    plt.title(model_name + " Confusion Matrix")
    plt.show()

# %%
evaluate_model(scratch_model, val_gray, "CNN ")
# Out:
# MODEL: CNN
#               precision    recall  f1-score   support
#
#        angry       0.60      0.59      0.59       958
#      disgust       0.67      0.56      0.61       111
#         fear       0.54      0.42      0.47      1024
#        happy       0.84      0.88      0.86      1774
#      neutral       0.62      0.66      0.64      1233
#          sad       0.55      0.58      0.56      1247
#     surprise       0.77      0.80      0.79       831
#
#     accuracy                           0.67      7178
#    macro avg       0.66      0.64      0.65      7178
# weighted avg       0.67      0.67      0.67      7178

# %%
evaluate_model(vgg_model, val_gray, "VGG Style")
# Out:
# MODEL: VGG Style
#               precision    recall  f1-score   support
#
#        angry       0.60      0.56      0.58       958
#      disgust       0.62      0.40      0.48       111
#         fear       0.57      0.30      0.39      1024
#        happy       0.87      0.88      0.87      1774
#      neutral       0.58      0.70      0.63      1233
#          sad       0.51      0.62      0.56      1247
#     surprise       0.77      0.81      0.79       831
#
#     accuracy                           0.66      7178
#    macro avg       0.65      0.61      0.62      7178
# weighted avg       0.66      0.66      0.65      7178

# %%
evaluate_model(pretrained_frozen_model, val_color, "MobileNet Frozen")
# Out:
# MODEL: MobileNet Frozen
#               precision    recall  f1-score   support
#
#        angry       0.41      0.49      0.45       958
#      disgust       0.56      0.30      0.39       111
#         fear       0.48      0.31      0.38      1024
#        happy       0.68      0.72      0.70      1774
#      neutral       0.46      0.51      0.49      1233
#          sad       0.45      0.42      0.44      1247
#     surprise       0.64      0.71      0.68       831
#
#     accuracy                           0.53      7178
#    macro avg       0.53      0.49      0.50      7178
# weighted avg       0.53      0.53      0.53      7178

# %%
evaluate_model(finetuned_model, val_color, "MobileNet Finetune")
# Out:
# MODEL: MobileNet Finetune
#               precision    recall  f1-score   support
#
#        angry       0.50      0.56      0.53       958
#      disgust       0.66      0.59      0.62       111
#         fear       0.51      0.47      0.49      1024
#        happy       0.77      0.81      0.79      1774
#      neutral       0.56      0.52      0.54      1233
#          sad       0.49      0.47      0.48      1247
#     surprise       0.75      0.75      0.75       831
#
#     accuracy                           0.61      7178
#    macro avg       0.61      0.60      0.60      7178
# weighted avg       0.61      0.61      0.61      7178

# %%
def get_model_accuracy(model, dataset, model_name):
    y_true, y_pred = [], []

    for x, y in dataset:
        preds = model.predict(x, verbose=0)

        y_pred.extend(np.argmax(preds, axis=1))
        y_true.extend(np.argmax(y.numpy(), axis=1))

    acc = accuracy_score(y_true, y_pred)

    return {
        "Model Name": model_name,
        "Accuracy": round(acc * 100, 2)
    }


# Collect results for all models
results = []

results.append(get_model_accuracy(scratch_model, val_gray, "CNN"))
results.append(get_model_accuracy(vgg_model, val_gray, "VGG Style"))
results.append(get_model_accuracy(pretrained_frozen_model, val_color, "MobileNet Frozen"))
results.append(get_model_accuracy(finetuned_model, val_color, "MobileNet Finetune"))


# Create comparison table
comparison_df = pd.DataFrame(results)

# Sort by best accuracy
comparison_df = comparison_df.sort_values(by="Accuracy", ascending=False).reset_index(drop=True)

print("\n ***** MODEL COMPARISON TABLE ***** \n")
print(comparison_df)


# Best model
best_model = comparison_df.iloc[0]

print("\n***** BEST MODEL *****\n")
print(f"Best Model: {best_model['Model Name']}")
print(f"Best Accuracy: {best_model['Accuracy']}%")
# Out:
#  ***** MODEL COMPARISON TABLE *****
#
#            Model Name  Accuracy
# 0                 CNN     67.14
# 1           VGG Style     66.19
# 2  MobileNet Finetune     61.10
# 3    MobileNet Frozen     53.47
#
# ***** BEST MODEL *****
#
# Best Model: CNN
# Best Accuracy: 67.14%

# %%
# Map all trained models exactly as used in notebook
model_map = {
    'CNN': (scratch_model, 'gray'),
    'VGG Style': (vgg_model, 'gray'),
    'MobileNet Frozen': (pretrained_frozen_model, 'color'),
    'MobileNet Finetune': (finetuned_model, 'color')
}

# Get best model using comparison table result
DEPLOY_MODEL, DEPLOY_MODE = model_map[best_model['Model Name']]

# Save model
DEPLOY_MODEL.save("emotion_model_deploy.h5")

print(f"Saved best model ({best_model['Model Name']}) → emotion_model_deploy.h5")
print(f"Input mode: {DEPLOY_MODE}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved best model (CNN) → emotion_model_deploy.h5
# Input mode: gray

# %%
from google.colab import files
files.download("emotion_model_deploy.h5")

# %%
# Get best model directly from comparison table
best_model_name = comparison_df.iloc[0]['Model Name']

# Model mapping
model_map = {
    'CNN': (scratch_model, 'gray'),
    'VGG Style': (vgg_model, 'gray'),
    'MobileNet Frozen': (pretrained_frozen_model, 'color'),
    'MobileNet Finetune': (finetuned_model, 'color')
}

# Select best model
DEPLOY_MODEL, DEPLOY_MODE = model_map[best_model_name]

# Save model
DEPLOY_MODEL.save(
    "emotion_model_deploy.keras",
    include_optimizer=False
)

print(f"Saved best model ({best_model_name}) → emotion_model_deploy.keras")
print(f"Input mode: {DEPLOY_MODE}")
# Out:
# Saved best model (CNN) → emotion_model_deploy.keras
# Input mode: gray

# %%
from google.colab import files
files.download("emotion_model_deploy.keras")

# %%
import tensorflow as tf
model = tf.keras.models.load_model("/content/emotion_model_deploy.keras", compile=False)
model.save("model.keras")

# %%
from google.colab import files
files.download("model.keras")
